# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv('diamonds_clean.csv')

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53932.000000  53932.000000  53932.000000  53932.000000  53932.000000
# mean       0.797862     61.749386     57.457011   3932.001539      5.731857
# std        0.473959      1.432462      2.234072   3988.577988      1.119896
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    949.750000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z  clarity_measurement  color_measurement
# count  53932.000000  53932.000000         53932.000000       53932.000000
# mean       5.733906      3.539623             3.051101           3.405826
# std        1.111749      0.691805             1.647109           1.701156
# min        3.680000      1.070000             0.000000           0.000000
# 25%        4.720000      2.910000             2.000000           2.000000
# 50%        5.710000      3.530000             3.000000           3.000000
# 75%        6.540000      4.040000             4.000000           5.000000
# max       11.419579      6.969200             7.000000           6.000000

# %%
#your comments here

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
#your hypotheses here
#The number of carat, the clarity of the diamond and its color are the features which should affect its price the most.

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
#your code here
diamonds.groupby(['color_measurement']).mean()
# Out:
#                       carat      depth      table        price         x  \
# color_measurement
# 0                  1.162137  61.887215  57.812393  5323.818020  6.519338
# 1                  1.026927  61.846385  57.577278  5091.874954  6.222826
# 2                  0.911496  61.836911  57.518239  4484.028189  5.984522
# 3                  0.771088  61.757449  57.288060  3998.145173  5.678549
# 4                  0.736544  61.694078  57.432998  3725.220755  5.616138
# 5                  0.657867  61.662090  57.491201  3076.752475  5.411580
# 6                  0.657715  61.698066  57.404355  3168.106436  5.417851
#
#                           y         z  clarity_measurement
# color_measurement
# 0                  6.518105  4.033243             2.776353
# 1                  6.222728  3.846369             2.964035
# 2                  5.979882  3.698621             2.934104
# 3                  5.681198  3.507966             3.463419
# 4                  5.620634  3.465788             3.134382
# 5                  5.416949  3.337767             2.969889
# 6                  5.421928  3.343320             2.691025

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
#We can see that the worst the colour is, the higher the diamond price is.

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
#distribution of the color
diamonds['color_measurement'].hist(bins=25)

# %%
#There are more diamonds which have a medium to worst color. We have a negatively skewed distribution.

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
diamonds.groupby(['carat']).mean()
# Out:
#            depth      table         price          x          y         z  \
# carat
# 0.20   61.100000  59.333333    365.166667   3.786667   3.753333  2.303333
# 0.21   60.511111  58.444444    380.222222   3.874444   3.837778  2.332222
# 0.22   61.620000  60.400000    391.400000   3.898000   3.848000  2.386000
# 0.23   61.426621  58.034130    486.143345   3.946382   3.973379  2.431468
# 0.24   61.599213  57.488189    505.185039   3.990157   4.019331  2.465591
# ...          ...        ...           ...        ...        ...       ...
# 4.00   63.300000  58.000000  15984.000000  10.010000   9.940000  6.310000
# 4.01   61.750000  61.500000  15223.000000  10.080000  10.014754  6.205000
# 4.13   64.800000  61.000000  17329.000000  10.000000   9.850000  6.431400
# 4.50   65.800000  58.000000  18531.000000  10.230000  10.160000  6.708310
# 5.01   65.500000  59.000000  18018.000000  10.740000  10.540000  6.969200
#
#        clarity_measurement  color_measurement
# carat
# 0.20              2.833333           5.166667
# 0.21              2.666667           5.444444
# 0.22              2.600000           4.800000
# 0.23              4.901024           4.518771
# 0.24              4.972441           4.185039
# ...                    ...                ...
# 4.00              0.000000           1.000000
# 4.01              0.000000           0.500000
# 4.13              0.000000           2.000000
# 4.50              0.000000           0.000000
# 5.01              0.000000           0.000000
#
# [273 rows x 8 columns]

# %%
#The higher the carat of the diamond is, the higher its price is.

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
#distribution of carat
diamonds['carat'].hist(bins=25)

# %%
#We have a positively skewed distribution with most of the diamonds wich are less than 1.5 carat.

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#Table mean
diamonds.groupby(['table']).mean()
# Out:
#         carat  depth    price      x      y      z  clarity_measurement  \
# table
# 43.0   1.0400  62.90   4997.0  6.450  6.410  4.040                 4.00
# 44.0   0.2900  62.80    474.0  4.200  4.240  2.650                 4.00
# 49.0   0.6500  64.25   2290.5  5.355  5.320  3.425                 3.00
# 50.0   1.5100  61.50   8995.5  7.380  7.295  4.510                 2.00
# 50.1   0.9400  66.00   3353.0  6.130  6.170  4.060                 1.00
# ...       ...    ...      ...    ...    ...    ...                  ...
# 71.0   0.6800  58.00   1633.0  5.850  5.700  3.350                 2.00
# 73.0   0.6025  68.90   2406.5  5.520  5.465  3.745                 3.25
# 76.0   0.7900  65.30   2362.0  5.520  5.130  3.350                 2.00
# 79.0   0.8100  68.80   2301.0  5.260  5.200  3.580                 1.00
# 95.0   2.0100  58.60  13387.0  8.320  8.310  4.870                 2.00
#
#        color_measurement
# table
# 43.0                 1.0
# 44.0                 5.0
# 49.0                 3.0
# 50.0                 3.0
# 50.1                 2.0
# ...                  ...
# 71.0                 3.0
# 73.0                 4.5
# 76.0                 3.0
# 79.0                 4.0
# 95.0                 4.0
#
# [127 rows x 8 columns]

# %%
#It doesn't really appear that the table value affect the diamond price.

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#Clarity mean
diamonds.groupby(['clarity_measurement']).mean()
# Out:
#                         carat      depth      table        price         x  \
# clarity_measurement
# 0                    1.283846  62.734278  58.303779  3924.168691  6.761093
# 1                    1.077501  61.771861  57.926714  5061.477802  6.403276
# 2                    0.850482  61.853042  57.662541  3996.001148  5.888383
# 3                    0.763850  61.724249  57.418040  3924.166204  5.658633
# 4                    0.727108  61.667968  57.313966  3839.144308  5.572860
# 5                    0.596202  61.663778  57.024990  3283.737071  5.218454
# 6                    0.503131  61.624521  56.883881  2519.512315  4.961721
# 7                    0.505123  61.510615  56.507207  2864.839106  4.968402
#
#                             y         z  color_measurement
# clarity_measurement
# 0                    6.709365  4.224656           2.968961
# 1                    6.394201  3.951987           3.470185
# 2                    5.888256  3.640636           3.448450
# 3                    5.659782  3.492788           3.494370
# 4                    5.580017  3.437925           3.161812
# 5                    5.232118  3.221465           3.569483
# 6                    4.976437  3.062132           3.350848
# 7                    4.989827  3.061659           3.101676

# %%
#It seems that better the diamond clarity is, the lesser its price is.

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
#Considering the results, the color, carat and clarity of the diamond seem to affect its price.

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#The graph between carat and price confirm that there is a positive correlation beteween the two.
#The pariplot also shows a positive correlation between x, y and z and the price.

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
#The matrix confirm that there is a positive correlation bewteen the price, x, y, z and the price. 
#So those are the variables which will affect the diamond price the most.
#However, the color and clarity don't have a correlation with the price contrary to our hypothesis.

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)
# Out:
# C:\Users\phola\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2
r2
# Out:
# 0.8493539446865919

# %% [markdown]
# **What do you think?**

# %%
#Roughly 85% of the variance found can be explained by the predictor variable. 
#So we can definitely say that this metric (carat) can be used to predict the price of the diamond.

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#We can also do the same with x,y or z. As we saw previoulsy that it has a pretty high correlation with the price.
#We will do the check on z.
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.z, diamonds.price, scatter=True)
# Out:
# C:\Users\phola\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.z, diamonds.price)
r2 = r_value ** 2
r2
# Out:
# 0.7779386052086611

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
